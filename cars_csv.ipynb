# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cars_df=pd.read_csv('C:\\Users\\GPT BANTWAL\\Downloads\\Cars931611042729436\\Cars93.csv')

# %%
columns=["Manufacturer","Model","Type","MPG.city","MPG.highway","Horsepower","Rear.seat.room","Passengers"]
cars_df[columns].head()
# Out:
#   Manufacturer    Model     Type  MPG.city  MPG.highway  Horsepower  \
# 0        Acura  Integra    Small        25           31         140
# 1        Acura   Legend  Midsize        18           25         200
# 2         Audi       90  Compact        20           26         172
# 3         Audi      100  Midsize        19           26         172
# 4          BMW     535i  Midsize        22           30         208
#
#    Rear.seat.room  Passengers
# 0            26.5           5
# 1            30.0           5
# 2            28.0           5
# 3            31.0           6
# 4            27.0           4

# %%
cars_df["Price"].plot(kind="box",figsize=(3,3))
# Out:
# <Axes: >

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
fig.set_figwidth(8)
fig.set_figheight(8)
ax1.boxplot(cars_df["Horsepower"])
ax2.boxplot(cars_df["MPG.city"])
ax1.set_title("Horsepower")
ax1.set_xlabel("Horsepower")
ax2.set_title("City Mileage")
ax2.set_xlabel("City Mileage(in miles per US gallon)")
fig.tight_layout()
